# %%
import cv2
import imutils
from imutils import perspective, contours
import numpy as np
from scipy.spatial import distance as dist
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/q6.jpeg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
def mid(a, b):
    mp = ((a[0] + b[0]) // 2, (a[1] + b[1]) // 2)

# %%
def process(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    edged = cv2.erode(cv2.dilate(cv2.Canny(gray, (5.0, 5.0), 0), None, iterations=1), None, iterations=1)
    contours = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)

    return contours

# %%
contours = process(img)
print(f"# Contours: {len(contours)}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 contours = process(img)
#       2 print(f"# Contours: {len(contours)}")
#
# Cell In[10], line 4, in process(img)
#       2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       3 gray = cv2.GaussianBlur(gray, (5, 5), 0)
# ----> 4 edged = cv2.erode(cv2.dilate(cv2.Canny(gray, (5.0, 5.0), 0), None, iterations=1), None, iterations=1)
#       5 contours = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#       6 contours = imutils.grab_contours(contours)
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'Canny'
# > Overload resolution failed:
# >  - Argument 'threshold1' can not be treated as a double
# >  - Argument 'threshold1' can not be treated as a double
# >  - Canny() missing required argument 'threshold2' (pos 4)
# >  - Canny() missing required argument 'threshold2' (pos 4)
