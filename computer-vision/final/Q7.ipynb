# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# ortho
img = cv2.imread('images/q7.1.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# ortho
img = cv2.imread('images/q7.2.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()
